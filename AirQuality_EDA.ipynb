# %% [markdown]
# <a href="https://colab.research.google.com/github/Priya7084/Data-Science-Eda-Project/blob/main/AirQuality_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df =  pd.read_excel('AirQualityUCI.xlsx')

# %%
# Display the first few rows
print(df.head())

# Get a summary of the dataset
print(df.info())

# Describe the dataset for basic statistical details
print(df.describe())
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH
# 0  13.60  48.875001  0.757754
# 1  13.30  47.700000  0.725487
# ...

# %%
# Displaying unique values count
print("\nUnique Values Count:")
print(df.nunique())
# Out:
# Unique Values Count:
# Date              391
# Time               24
# CO(GT)             97
# PT08.S1(CO)      3246
# NMHC(GT)          430
# C6H6(GT)         3773
# PT08.S2(NMHC)    3773
# NOx(GT)          2467
# PT08.S3(NOx)     3519
# NO2(GT)          1420
# PT08.S4(NO2)     4408
# PT08.S5(O3)      4679
# T                3368
# RH               4903
# AH               8988
# dtype: int64

# %%
# Visualizing missing values using a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograms for numerical features
df.hist(bins=30, figsize=(20, 15))
plt.suptitle('Histograms of Numeric Columns')
plt.show()

# Box plots for numerical features
plt.figure(figsize=(10, 5))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.show()
